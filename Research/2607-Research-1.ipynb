# %%
import re
import pandas as pd
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

#Moduly
from DataLoader import *

# %% [markdown]
# # Some info and EDA

# %% [markdown]
# Troche tutaj opiszę - to będzie dobra praktyka wniosków o danych
# W obecnym notebook mamy pare informacji:
# - data shape (486, 25)
# - wszystkie wartości są unikalne
# - brak jest braków xd
# - ['Thalasse', 'Diabetes', 'Heart Di', 'Anemia', 'Thromboc', 'Healthy'] takie mamy rodzaje chorób
#
# Thalasse: 48 |
# Diabetes: 294 |
# Heart Di: 39 |
# Anemia: 84 |
# Thromboc: 16 |
# Healthy: 5 |
# - Tyle jest chorób - widać że przeważają Diabetes

# %%
data = DataLoader('/Users/antonio/Desktop/Hematology/Research/archive/blood_samples_dataset_test.csv')
df = data.load()

# %%
df
# Out:
#       Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0    0.001827     0.033693    0.114755   0.997927           0.562604
# 1    0.436679     0.972653    0.084998   0.180909           0.675736
# 2    0.545697     0.324815    0.584467   0.475748           0.558596
# 3    0.172994     0.050351    0.736000   0.782022           0.069435
# 4    0.758534     0.739968    0.597868   0.772683           0.875720
# ..        ...          ...         ...        ...                ...
# 481  0.985163     0.412960    0.529993   0.263765           0.431288
# 482  0.581914     0.629325    0.491644   0.901473           0.347797
# 483  0.066669     0.404558    0.591041   0.228401           0.127461
# 484  0.901444     0.430680    0.243853   0.825551           0.493884
# 485  0.877912     0.597809    0.730440   0.462307           0.498438
#
#      Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0           0.866499    0.578042                 0.914615
# ...

# %%
df.shape
# Out:
# (486, 25)

# %%
df.describe()
# Out:
#           Glucose  Cholesterol  Hemoglobin   Platelets  White Blood Cells  \
# count  486.000000   486.000000  486.000000  486.000000         486.000000
# mean     0.490044     0.506797    0.485502    0.528136           0.509783
# std      0.284196     0.282871    0.298818    0.292610           0.290887
# min      0.001827     0.003088    0.000719    0.000006          -0.000206
# 25%      0.236664     0.268021    0.201994    0.276155           0.264944
# 50%      0.496471     0.502397    0.477706    0.538642           0.511102
# 75%      0.727144     0.754638    0.750028    0.789486           0.767896
# max      0.991742     0.999606    0.997876    0.999507           0.999646
#
#        Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# count       486.000000  486.000000               486.000000
# mean          0.504347    0.501042                 0.516185
# std           0.302865    0.294501                 0.279954
# ...

# %%
df.nunique()
# Out:
# Glucose                                      486
# Cholesterol                                  486
# Hemoglobin                                   486
# Platelets                                    486
# White Blood Cells                            486
# Red Blood Cells                              486
# Hematocrit                                   486
# Mean Corpuscular Volume                      486
# Mean Corpuscular Hemoglobin                  486
# Mean Corpuscular Hemoglobin Concentration    486
# Insulin                                      486
# BMI                                          486
# Systolic Blood Pressure                      486
# Diastolic Blood Pressure                     486
# Triglycerides                                486
# HbA1c                                        486
# LDL Cholesterol                              486
# HDL Cholesterol                              486
# ALT                                          486
# ...

# %%
df.isna().sum()
# Out:
# Glucose                                      0
# Cholesterol                                  0
# Hemoglobin                                   0
# Platelets                                    0
# White Blood Cells                            0
# Red Blood Cells                              0
# Hematocrit                                   0
# Mean Corpuscular Volume                      0
# Mean Corpuscular Hemoglobin                  0
# Mean Corpuscular Hemoglobin Concentration    0
# Insulin                                      0
# BMI                                          0
# Systolic Blood Pressure                      0
# Diastolic Blood Pressure                     0
# Triglycerides                                0
# HbA1c                                        0
# LDL Cholesterol                              0
# HDL Cholesterol                              0
# ALT                                          0
# AST                                          0
# ...

# %%
df.columns
# Out:
# Index(['Glucose', 'Cholesterol', 'Hemoglobin', 'Platelets',
#        'White Blood Cells', 'Red Blood Cells', 'Hematocrit',
#        'Mean Corpuscular Volume', 'Mean Corpuscular Hemoglobin',
#        'Mean Corpuscular Hemoglobin Concentration', 'Insulin', 'BMI',
#        'Systolic Blood Pressure', 'Diastolic Blood Pressure', 'Triglycerides',
#        'HbA1c', 'LDL Cholesterol', 'HDL Cholesterol', 'ALT', 'AST',
#        'Heart Rate', 'Creatinine', 'Troponin', 'C-reactive Protein',
#        'Disease'],
#       dtype='object')

# %%
columns = df['Disease'].unique().tolist()

# %%
disease_counts = defaultdict(int)
for c in df['Disease']:
    disease_counts[c] +=1

for disease, count in disease_counts.items():
    print(f"{disease}: {count}")
# Out:
# Thalasse: 48
# Diabetes: 294
# Heart Di: 39
# Anemia: 84
# Thromboc: 16
# Healthy: 5

# %% [markdown]
# ### Encode wartosci Disease

# %%
df_encoded = pd.get_dummies(df, columns=['Disease'], drop_first=False)

# %%
df_encoded.shape
# Out:
# (486, 30)

# %% [markdown]
# ## Correlation Matrix

# %%
num_cols = df_encoded.select_dtypes(include=['int64','float64'])
corr = num_cols.corr(method='pearson')
plt.figure(figsize=(10,8))
plt.imshow(corr, aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.index)
plt.title('Macierz korelacji cech')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Future Importance

# %%
from scipy.stats import pearsonr
x = df['Glucose']
y = df['Hemoglobin']

# funkcja pearsonr zwraca (r, p-value)
r, p = pearsonr(x, y)
print(f"Pearson r = {r:.3f}, p-value = {p:.3e}")
# Out:
# Pearson r = -0.034, p-value = 4.557e-01
