# %%
import pandas as pd

# %%
df = pd.read_csv("models/anemia/synthetic_data_realistic_original.csv")

# %%
df.head()
# Out:
#          WBC     NEUT#    LYMPH#      ALY#     ASLY#     MONO#      EOS#  \
# 0  12.509665  2.582740  0.760880  0.130517  0.000000  0.669411  0.217803
# 1   6.910630  6.032525  1.447419  0.000000  0.047754  0.000000  0.152524
# 2   7.922858  6.603139  1.951306  0.084319  0.024396  0.701116  0.241729
# 3   6.969292  4.240557  1.959089  0.000000  0.016695  0.331444  0.130386
# 4   1.980545  1.639358  1.886398  0.038452  0.086294  0.000000  0.000000
#
#       BASO#      NEUT%     LYMPH%  ...  Mikrocyty  Makrocyty     NRBC#  \
# 0  0.002259  49.943360  36.337857  ...   1.056343   2.153055  0.017301
# 1  0.041919  57.068648  29.843956  ...   0.647989   0.000000  0.018124
# 2  0.048173  62.366798  24.396971  ...   4.263521   2.873285  0.000000
# 3  0.053954  66.353288  20.157155  ...   0.152987   0.545844  0.027134
# 4  0.000000  55.270172  31.989248  ...   2.112127   0.000000  0.038089
#
#       NRBC%         PLT        PDW        MPV       PLCR       PCT  \
# ...

# %%
df.isnull().sum()
# Out:
# WBC          0
# NEUT#        0
# LYMPH#       0
# ALY#         0
# ASLY#        0
# MONO#        0
# EOS#         0
# BASO#        0
# NEUT%        0
# LYMPH%       0
# ALY%         0
# ASLY%        0
# MONO%        0
# EOS%         0
# BASO%        0
# NEUT-GI      0
# NEUT-RI      0
# RBC          0
# HGB          0
# HCT          0
# MCV          0
# MCH          0
# MCHC         0
# RDW-SD       0
# RDW-CV       0
# Mikrocyty    0
# Makrocyty    0
# NRBC#        0
# NRBC%        0
# PLT          0
# PDW          0
# MPV          0
# PLCR         0
# PCT          0
# Label        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27496 entries, 0 to 27495
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WBC        27496 non-null  float64
#  1   NEUT#      27496 non-null  float64
#  2   LYMPH#     27496 non-null  float64
#  3   ALY#       27496 non-null  float64
#  4   ASLY#      27496 non-null  float64
#  5   MONO#      27496 non-null  float64
#  6   EOS#       27496 non-null  float64
#  7   BASO#      27496 non-null  float64
#  8   NEUT%      27496 non-null  float64
#  9   LYMPH%     27496 non-null  float64
#  10  ALY%       27496 non-null  float64
#  11  ASLY%      27496 non-null  float64
#  12  MONO%      27496 non-null  float64
#  13  EOS%       27496 non-null  float64
#  14  BASO%      27496 non-null  float64
#  15  NEUT-GI    27496 non-null  float64
#  16  NEUT-RI    27496 non-null  float64
#  17  RBC        27496 non-null  float64
#  18  HGB        27496 non-null  float64
# ...

# %%
df.shape
# Out:
# (27496, 35)
